# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-e0d77110-29cf-46e0-80fb-8e9d165bd966" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e0d77110-29cf-46e0-80fb-8e9d165bd966">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df= pd.read_csv('Athletes.csv')
print(df)
# Out:
#          Bib    Zip  Age Age Group Gender  First Half  Second Half  Finish  \
# 0         25  93730   30  Under 35      M        3832         3961    7793
# 1          9  97124   32  Under 35      M        3845         4059    7904
# 2         20  80922   40     40-44      M        3795         4157    7952
# 3         46   2136   38     35-39      M        3997         4065    8062
# 4         51   6119   26  Under 35      M        3979         4198    8177
# ...      ...    ...  ...       ...    ...         ...          ...     ...
# 17215   7691  28075   45     45-49      M        7286        17096   24382
# 17216   7771  37419   63     60-64      M       10891        13701   24592
# 17217  15778  29575   66     65-69      M       11957        12829   24786
# 17218   7318  20906   40     40-44      M       11536        13915   25451
# 17219   7786  76259   44     40-44      M       12057        13809   25866
#
#        Positive Split  Percent Change
# ...

# %%
import pandas as pd

df= pd.read_csv('Athletes.csv')
print(df.head(10))
# Out:
#    Bib    Zip  Age Age Group Gender  First Half  Second Half  Finish  \
# 0   25  93730   30  Under 35      M        3832         3961    7793
# 1    9  97124   32  Under 35      M        3845         4059    7904
# 2   20  80922   40     40-44      M        3795         4157    7952
# 3   46   2136   38     35-39      M        3997         4065    8062
# 4   51   6119   26  Under 35      M        3979         4198    8177
# 5   36  90291   23  Under 35      M        3973         4215    8188
# 6   43  72712   27  Under 35      M        3979         4249    8228
# 7   37  81101   29  Under 35      M        4069         4257    8326
# 8   47   2451   41     40-44      M        4122         4268    8390
# 9   30  14850   33  Under 35      M        4004         4392    8396
#
#    Positive Split  Percent Change
# 0             129        0.033664
# 1             214        0.055657
# 2             362        0.095389
# 3              68        0.017013
# ...

# %%
import matplotlib.pyplot as plt

x= ['fisrt half','second half','finish']
y= [[3832,3845,3795,3997,3979],
    [3961,4059,4157,4065,4198],
    [7793,7904,7952,8062,8177]]
plt.plot(x,y)
print(plt.title('Athletes Performance'))
print(plt.xlabel('Stages'))
print(plt.ylabel('Number of Athletes'))
plt.show()
# Out:
# Text(0.5, 1.0, 'Athletes Performance')
# Text(0.5, 0, 'Stages')
# Text(0, 0.5, 'Number of Athletes')

# %%
import numpy as np
import matplotlib.pyplot as plt

x= np.array(['fisrt half','second half','finish'])
y= np.array([[3832,3845,3795,3997,3979],
    [3961,4059,4157,4065,4198],
    [7793,7904,7952,8062,8177]])
plt.title('Athletes Performance')
plt.xlabel('Stages')
plt.ylabel('Number of Athletes')
plt.grid(color='maroon',linestyle='--', linewidth=1)
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x= np.array(['fisrt half','second half','finish'])
y= np.array([3832,3845,3795])
plt.title('Athletes Performance')
plt.xlabel('Stages')
plt.ylabel('Number of Athletes')
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
labels = ['firat half', 'second half', 'finish']
sizes = [3832,3845,3879]

#plot
fig, ax = plt.subplots(figsize=(10, 6), subplot_kw=dict(aspect="equal"))

wedges, texts = ax.pie(sizes, wedgeprops=dict(width=0.5), startangle=-50)

# Inner circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Add labels
ax.legend(wedges, labels,
      title="number of athletes",
      loc="center right",
      bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(texts, size=12, weight="bold")

ax.set_title("athletes performance")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

x= [30,33,40]
y= [3832,3845,3795]
plt.title('Athletes Performance')
plt.xlabel('Stages')
plt.ylabel('Number of Athletes')
sns.distplot(x,bins=5)
plt.show()
# Out:
# <ipython-input-44-e577b1ffc68a>:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x,bins=5)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

A= (['fisrt half','second half','finish'])
B= [3832,3845,3795]
sns.countplot(x=A, hue=B)
plt.title('Athletes Performance')
plt.xlabel('Stages')
plt.ylabel('Number of Athletes')
plt.show()

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-52527cf3-1288-43f5-986e-e0e3a4e8fd8e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-52527cf3-1288-43f5-986e-e0e3a4e8fd8e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df= pd.read_csv('emissions_high_granularity.csv')
print(df.head(30))
# Out:
#     year                   parent_entity         parent_type  \
# 0   1962  Abu Dhabi National Oil Company  State-owned Entity
# 1   1963  Abu Dhabi National Oil Company  State-owned Entity
# 2   1964  Abu Dhabi National Oil Company  State-owned Entity
# 3   1965  Abu Dhabi National Oil Company  State-owned Entity
# 4   1966  Abu Dhabi National Oil Company  State-owned Entity
# 5   1967  Abu Dhabi National Oil Company  State-owned Entity
# 6   1968  Abu Dhabi National Oil Company  State-owned Entity
# 7   1969  Abu Dhabi National Oil Company  State-owned Entity
# 8   1970  Abu Dhabi National Oil Company  State-owned Entity
# 9   1971  Abu Dhabi National Oil Company  State-owned Entity
# 10  1972  Abu Dhabi National Oil Company  State-owned Entity
# 11  1973  Abu Dhabi National Oil Company  State-owned Entity
# 12  1974  Abu Dhabi National Oil Company  State-owned Entity
# 13  1975  Abu Dhabi National Oil Company  State-owned Entity
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(24, 18))
sns.countplot(y=df['parent_entity'])
plt.title('Count of Parent Entities')
plt.show()

sns.countplot(y=df['commodity'])
plt.title('Count of Commodities')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='year', y='production_value', hue='commodity')
plt.title('Production Value Over Years by Commodity')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df= pd.read_csv('emissions_high_granularity.csv')

commodity_counts = df['commodity'].value_counts()
plt.figure(figsize=(10, 6))
plt.pie(commodity_counts, labels=commodity_counts.index,autopct='%1.1f%%',  startangle=140)
plt.title('Commodity Distribution')
plt.axis('equal')
plt.show()
